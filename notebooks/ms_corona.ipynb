# %%
import pandas as pd
import locale
import seaborn as sns
import matplotlib.pyplot as plt

from ms_corona.scraper import main
from ms_corona.data_processing import cast_date_column

# %%
df = main()

# %%
df.dtypes
# Out:
# datum        object
# infiziert     int64
# genesen       int64
# gestorben     int64
# kommentar    object
# dtype: object

# %%
df = cast_date_column(df)
df.dtypes
# Out:
# datum        datetime64[ns]
# infiziert             int64
# genesen               int64
# gestorben             int64
# kommentar            object
# dtype: object

# %%
sns.lineplot(x="datum",y="infiziert", data=df)

# %%
sns.lineplot(x="datum",y="genesen", data=df)
